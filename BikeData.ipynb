# %% [markdown]
# ## Bike Data set

# %%
import pandas as pd
import numpy as np
bikeData=pd.read_csv('/Users/shreya/Desktop/Python Datasets/Regression Datasets/BikeRentData.csv', encoding='latin')
print('Shape before deleting duplicate values:', bikeData.shape)

# Removing duplicate rows if any
bikeData=bikeData.drop_duplicates()
print('Shape After deleting duplicate values:', bikeData.shape)

bikeData.head(10)
# Out:
# Shape before deleting duplicate values: (17379, 15)
# Shape After deleting duplicate values: (17379, 15)
#    Unnamed: 0  season  yr  mnth  hr  holiday  weekday  workingday  weathersit  \
# 0           1       1   0     1   0        0        6           0           1
# 1           2       1   0     1   1        0        6           0           1
# 2           3       1   0     1   2        0        6           0           1
# 3           4       1   0     1   3        0        6           0           1
# 4           5       1   0     1   4        0        6           0           1
# 5           6       1   0     1   5        0        6           0           2
# 6           7       1   0     1   6        0        6           0           1
# 7           8       1   0     1   7        0        6           0           1
# 8           9       1   0     1   8        0        6           0           1
# 9          10       1   0     1   9        0        6           0           1
#
# ...

# %%
bikeData.drop('Unnamed: 0',
  axis='columns', inplace=True)

# %%
bikeData.head()
# Out:
#    season  yr  mnth  hr  holiday  weekday  workingday  weathersit  temp  \
# 0       1   0     1   0        0        6           0           1  0.24
# 1       1   0     1   1        0        6           0           1  0.22
# 2       1   0     1   2        0        6           0           1  0.22
# 3       1   0     1   3        0        6           0           1  0.24
# 4       1   0     1   4        0        6           0           1  0.24
#
#     atemp   hum  windspeed  registered  cnt
# 0  0.2879  0.81        0.0          13   16
# 1  0.2727  0.80        0.0          32   40
# 2  0.2727  0.80        0.0          27   32
# 3  0.2879  0.75        0.0          10   13
# 4  0.2879  0.75        0.0           1    1

# %%
bikeData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17379 entries, 0 to 17378
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      17379 non-null  int64
#  1   yr          17379 non-null  int64
#  2   mnth        17379 non-null  int64
#  3   hr          17379 non-null  int64
#  4   holiday     17379 non-null  int64
#  5   weekday     17379 non-null  int64
#  6   workingday  17379 non-null  int64
#  7   weathersit  17379 non-null  int64
#  8   temp        17379 non-null  float64
#  9   atemp       17379 non-null  float64
#  10  hum         17379 non-null  float64
#  11  windspeed   17379 non-null  float64
#  12  registered  17379 non-null  int64
#  13  cnt         17379 non-null  int64
# dtypes: float64(4), int64(10)
# memory usage: 2.0 MB

# %%
# %matplotlib inline
bikeData.hist(['cnt'], figsize=[10,3])
# Out:
# array([[<AxesSubplot:title={'center':'cnt'}>]], dtype=object)

# %%
bikeData.nunique()
# Out:
# season          4
# yr              2
# mnth           12
# hr             24
# holiday         2
# weekday         7
# workingday      2
# weathersit      4
# temp           50
# atemp          65
# hum            89
# windspeed      30
# registered    776
# cnt           869
# dtype: int64

# %%
bikeData.corr()
# Out:
#               season        yr      mnth        hr   holiday   weekday  \
# season      1.000000 -0.010742  0.830386 -0.006117 -0.009585 -0.002335
# yr         -0.010742  1.000000 -0.010473 -0.003867  0.006692 -0.004485
# mnth        0.830386 -0.010473  1.000000 -0.005772  0.018430  0.010400
# hr         -0.006117 -0.003867 -0.005772  1.000000  0.000479 -0.003498
# holiday    -0.009585  0.006692  0.018430  0.000479  1.000000 -0.102088
# weekday    -0.002335 -0.004485  0.010400 -0.003498 -0.102088  1.000000
# workingday  0.013743 -0.002196 -0.003477  0.002285 -0.252471  0.035955
# weathersit -0.014524 -0.019157  0.005400 -0.020203 -0.017036  0.003311
# temp        0.312025  0.040913  0.201691  0.137603 -0.027340 -0.001795
# atemp       0.319380  0.039222  0.208096  0.133750 -0.030973 -0.008821
# hum         0.150625 -0.083546  0.164411 -0.276498 -0.010588 -0.037158
# windspeed  -0.149773 -0.008740 -0.135386  0.137252  0.003988  0.011502
# ...

# %%
bikeData.columns
# Out:
# Index(['season', 'yr', 'mnth', 'hr', 'holiday', 'weekday', 'workingday',
#        'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'registered', 'cnt'],
#       dtype='object')

# %%
def PlotBarCharts(inpData, colsToPlot):
    # %matplotlib inline
    
    import matplotlib.pyplot as plt
    
    # Generating multiple subplots
    fig, subPlot=plt.subplots(nrows=1, ncols=len(colsToPlot), figsize=(18,5))
    fig.suptitle('Bar charts of: '+ str(colsToPlot))

    for colName, plotNumber in zip(colsToPlot, range(len(colsToPlot))):
        inpData.groupby(colName).size().plot(kind='bar',ax=subPlot[plotNumber])

# Calling the function
PlotBarCharts(inpData=bikeData, colsToPlot=['season', 'yr', 'mnth', 'holiday', 'weekday', 'workingday',
       'weathersit'])

# %%
bikeData.hist(['temp', 'atemp', 'hum', 'windspeed', 'registered'], figsize=(18,8))
# Out:
# array([[<AxesSubplot:title={'center':'temp'}>,
#         <AxesSubplot:title={'center':'atemp'}>],
#        [<AxesSubplot:title={'center':'hum'}>,
#         <AxesSubplot:title={'center':'windspeed'}>],
#        [<AxesSubplot:title={'center':'registered'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
FullDataPlot=pd.plotting.scatter_matrix(bikeData, figsize=(20,20))

# %%
import matplotlib.pyplot as plt

# Generating multiple subplots
fig, subPlot=plt.subplots(nrows=1, ncols=4, figsize=(18,5))

# Creating the super title of the charts
#fig.suptitle('Price Vs AGE, KM and Weight')
#['temp', 'atemp', 'hum', 'windspeed', 'registered']
# Generating multiple scatter charts
bikeData.plot.scatter(x='temp', y='cnt', marker='o', color='blue', ax=subPlot[0])
bikeData.plot.scatter(x='atemp', y='cnt', marker='o', color='blue', ax=subPlot[1])
bikeData.plot.scatter(x='hum', y='cnt', marker='o', color='blue', ax=subPlot[2])
bikeData.plot.scatter(x='windspeed', y='cnt', marker='o', color='blue', ax=subPlot[3])
# Out:
# <AxesSubplot:xlabel='windspeed', ylabel='cnt'>

# %%
from scipy.stats import f_oneway
def FunctionAnova(inputData, targetVar, categoricalPredictors):
  
    for i in categoricalPredictors:
        CategoryGroupList= inputData.groupby(i)[targetVar].apply(list)
        AnovaResults = f_oneway(*CategoryGroupList)
        print('P-Value for Anova of',i,' type is: ', AnovaResults[1])
        
    
FunctionAnova(inputData=bikeData, targetVar='cnt', categoricalPredictors=['season', 'yr', 'mnth', 'holiday', 'weekday', 'workingday',
       'weathersit'])
# Out:
# P-Value for Anova of season  type is:  7.40107139971279e-257
# P-Value for Anova of yr  type is:  7.213184208630547e-247
# P-Value for Anova of mnth  type is:  5.505684936484358e-284
# P-Value for Anova of holiday  type is:  4.5461689487233316e-05
# P-Value for Anova of weekday  type is:  0.0018990310434750582
# P-Value for Anova of workingday  type is:  6.524264547051995e-05
# P-Value for Anova of weathersit  type is:  1.7347820521803117e-81

# %%
bikeData.corr()
# Out:
#               season        yr      mnth        hr   holiday   weekday  \
# season      1.000000 -0.010742  0.830386 -0.006117 -0.009585 -0.002335
# yr         -0.010742  1.000000 -0.010473 -0.003867  0.006692 -0.004485
# mnth        0.830386 -0.010473  1.000000 -0.005772  0.018430  0.010400
# hr         -0.006117 -0.003867 -0.005772  1.000000  0.000479 -0.003498
# holiday    -0.009585  0.006692  0.018430  0.000479  1.000000 -0.102088
# weekday    -0.002335 -0.004485  0.010400 -0.003498 -0.102088  1.000000
# workingday  0.013743 -0.002196 -0.003477  0.002285 -0.252471  0.035955
# weathersit -0.014524 -0.019157  0.005400 -0.020203 -0.017036  0.003311
# temp        0.312025  0.040913  0.201691  0.137603 -0.027340 -0.001795
# atemp       0.319380  0.039222  0.208096  0.133750 -0.030973 -0.008821
# hum         0.150625 -0.083546  0.164411 -0.276498 -0.010588 -0.037158
# windspeed  -0.149773 -0.008740 -0.135386  0.137252  0.003988  0.011502
# ...

# %% [markdown]
# ## yr, hr, temp,atemp, hum, registered

# %%
bikeData.isnull().sum()
# Out:
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# registered    0
# cnt           0
# dtype: int64

# %%
bikeDataNumeric=bikeData.drop(['season', 'mnth','holiday', 'weekday', 'workingday',
       'weathersit', 'windspeed'],
  axis='columns', inplace=False)

# %%
bikeDataNumeric.head()
# Out:
#    yr  hr  temp   atemp   hum  registered  cnt
# 0   0   0  0.24  0.2879  0.81          13   16
# 1   0   1  0.22  0.2727  0.80          32   40
# 2   0   2  0.22  0.2727  0.80          27   32
# 3   0   3  0.24  0.2879  0.75          10   13
# 4   0   4  0.24  0.2879  0.75           1    1

# %%
bikeDataNumeric.columns
# Out:
# Index(['yr', 'hr', 'temp', 'atemp', 'hum', 'registered', 'cnt'], dtype='object')

# %%
TargetVariable='cnt'
Predictors=[ 'hr', 'temp', 'atemp', 'hum', 'registered']
X=bikeDataNumeric[Predictors].values
y=bikeDataNumeric[TargetVariable].values

# Split the data into training and testing set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (13034, 5)
# (13034,)
# (4345, 5)
# (4345,)

# %% [markdown]
# ## Multiple Linear Regressor

# %%
from sklearn.linear_model import LinearRegression
RegModel = LinearRegression()

# Printing all the parameters of Linear regression
print(RegModel)

# Creating the model on Training Data
LREG=RegModel.fit(X_train,y_train)
prediction=LREG.predict(X_test)

from sklearn import metrics
# Measuring Goodness of fit in Training data
print('R2 Value:',metrics.r2_score(y_train, LREG.predict(X_train)))

# Measuring accuracy on Testing Data
print('Accuracy on Test Data:',100- (np.mean(np.abs((y_test - prediction) / y_test)) * 100))

# Printing some sample values of prediction
TestingDataResults=pd.DataFrame(data=X_test, columns=Predictors)
TestingDataResults[TargetVariable]=y_test
TestingDataResults[('Predicted'+TargetVariable)]=np.round(prediction)
TestingDataResults.head()
# Out:
# LinearRegression()
# R2 Value: 0.9562123990646201
# Accuracy on Test Data: 46.23135224090264
#      hr  temp   atemp   hum  registered  cnt  Predictedcnt
# 0  19.0  0.80  0.6970  0.27       240.0  425         332.0
# 1  20.0  0.24  0.2273  0.41        83.0   88         106.0
# 2   2.0  0.32  0.3030  0.66         3.0    4           1.0
# 3  19.0  0.78  0.7121  0.52       457.0  526         557.0
# 4   0.0  0.26  0.2273  0.56         8.0   13           5.0

# %%
import matplotlib.pyplot as plt
plt.scatter(x=TestingDataResults['temp'] , y=TestingDataResults['cnt'])
plt.plot(TestingDataResults['temp'] , TestingDataResults['Predictedcnt'], color='red')

# %%
TestingDataResults['APE']= np.abs((y_test - prediction) / y_test) * 100

# Printing the top 10 errors made by the model
TestingDataResults.sort_values(by='APE', ascending=False).head(10)
# Out:
#        hr  temp   atemp   hum  registered  cnt  Predictedcnt          APE
# 3082  2.0  0.14  0.1515  0.86         1.0    1         -27.0  2828.525582
# 3110  3.0  0.28  0.2727  1.00         0.0    1         -24.0  2492.417309
# 4186  4.0  0.20  0.1515  0.80         0.0    1         -21.0  2225.083636
# 1454  5.0  0.12  0.1667  0.74         1.0    1         -19.0  2012.434283
# 594   3.0  0.28  0.2727  0.93         1.0    1         -19.0  1995.345712
# 4260  4.0  0.28  0.2727  0.93         1.0    1         -18.0  1937.508819
# 3506  3.0  0.58  0.5455  0.68         1.0    1          20.0  1935.909272
# 4120  4.0  0.38  0.3939  0.43         1.0    1          19.0  1811.591200
# 2286  4.0  0.20  0.2121  0.75         0.0    1         -16.0  1678.003548
# 3414  5.0  0.20  0.1818  0.75         1.0    1         -15.0  1645.413163

# %% [markdown]
# ## Decision tree

# %%
from sklearn.tree import DecisionTreeRegressor
RegModel = DecisionTreeRegressor(max_depth=7,criterion='mse')

# Printing all the parameters of Random Forest
print(RegModel)

# Creating the model on Training Data
DT=RegModel.fit(X_train,y_train)
prediction=DT.predict(X_test)

from sklearn import metrics
# Measuring Goodness of fit in Training data
print('R2 Value:',metrics.r2_score(y_train, DT.predict(X_train)))

# Measuring accuracy on Testing Data
print('Accuracy',100- (np.mean(np.abs((y_test - prediction) / y_test)) * 100))

# Plotting the feature importance for Top 10 most important columns
# %matplotlib inline
feature_importances = pd.Series(DT.feature_importances_, index=Predictors)
feature_importances.nlargest(10).plot(kind='barh')

# Printing some sample values of prediction
TestingDataResults=pd.DataFrame(data=X_test, columns=Predictors)
TestingDataResults[TargetVariable]=y_test
TestingDataResults[('Predicted'+TargetVariable)]=np.round(prediction)
TestingDataResults.head()
# Out:
# DecisionTreeRegressor(max_depth=7)
# R2 Value: 0.9749323132001262
# Accuracy 87.39020588014212
#      hr  temp   atemp   hum  registered  cnt  Predictedcnt
# 0  19.0  0.80  0.6970  0.27       240.0  425         320.0
# 1  20.0  0.24  0.2273  0.41        83.0   88          91.0
# 2   2.0  0.32  0.3030  0.66         3.0    4           4.0
# 3  19.0  0.78  0.7121  0.52       457.0  526         544.0
# 4   0.0  0.26  0.2273  0.56         8.0   13          11.0

# %%
# !pip install graphviz

# %%
import os
os.environ["PATH"] += os.pathsep + 'C:\\Users\\shreya\\AppData\\Local\\Continuum\\Anaconda3\\Library\\bin\\graphviz'

# %% [markdown]
# ## Random forest

# %%
from sklearn.ensemble import RandomForestRegressor
RegModel = RandomForestRegressor(max_depth=9, n_estimators=160,criterion='mse')

# Good range for max_depth: 2-10 and n_estimators: 100-1000

# Printing all the parameters of Random Forest
print(RegModel)

# Creating the model on Training Data
RF=RegModel.fit(X_train,y_train)
prediction=RF.predict(X_test)

from sklearn import metrics
# Measuring Goodness of fit in Training data
print('R2 Value:',metrics.r2_score(y_train, RF.predict(X_train)))

# Measuring accuracy on Testing Data
print('Accuracy',100- (np.mean(np.abs((y_test - prediction) / y_test)) * 100))

# Plotting the feature importance for Top 10 most important columns
# %matplotlib inline
feature_importances = pd.Series(RF.feature_importances_, index=Predictors)
feature_importances.nlargest(10).plot(kind='barh')

# Printing some sample values of prediction
TestingDataResults=pd.DataFrame(data=X_test, columns=Predictors)
TestingDataResults[TargetVariable]=y_test
TestingDataResults[('Predicted'+TargetVariable)]=np.round(prediction)
TestingDataResults.head()
# Out:
# RandomForestRegressor(max_depth=9, n_estimators=160)
# R2 Value: 0.9841434902338758
# Accuracy 89.3588704467111
#      hr  temp   atemp   hum  registered  cnt  Predictedcnt
# 0  19.0  0.80  0.6970  0.27       240.0  425         342.0
# 1  20.0  0.24  0.2273  0.41        83.0   88          90.0
# 2   2.0  0.32  0.3030  0.66         3.0    4           3.0
# 3  19.0  0.78  0.7121  0.52       457.0  526         542.0
# 4   0.0  0.26  0.2273  0.56         8.0   13          10.0

# %% [markdown]
# ## Adaboost

# %%
# Adaboost (Boosting of multiple Decision Trees)
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor

# Choosing Decision Tree with 1 level as the weak learner
DTR=DecisionTreeRegressor(max_depth=10)
RegModel = AdaBoostRegressor(n_estimators=200, base_estimator=DTR ,learning_rate=0.1)

# Printing all the parameters of Adaboost
print(RegModel)

# Creating the model on Training Data
AB=RegModel.fit(X_train,y_train)
prediction=AB.predict(X_test)

from sklearn import metrics
# Measuring Goodness of fit in Training data
print('R2 Value:',metrics.r2_score(y_train, AB.predict(X_train)))

# Measuring accuracy on Testing Data
print('Accuracy',100- (np.mean(np.abs((y_test - prediction) / y_test)) * 100))

# Plotting the feature importance for Top 10 most important columns
# %matplotlib inline
feature_importances = pd.Series(AB.feature_importances_, index=Predictors)
feature_importances.nlargest(10).plot(kind='barh')

# Printing some sample values of prediction
TestingDataResults=pd.DataFrame(data=X_test, columns=Predictors)
TestingDataResults[TargetVariable]=y_test
TestingDataResults[('Predicted'+TargetVariable)]=np.round(prediction)
TestingDataResults.head()
# Out:
# AdaBoostRegressor(base_estimator=DecisionTreeRegressor(max_depth=10),
#                   learning_rate=0.1, n_estimators=200)
# R2 Value: 0.9917562320140098
# Accuracy 89.3492491258882
#      hr  temp   atemp   hum  registered  cnt  Predictedcnt
# 0  19.0  0.80  0.6970  0.27       240.0  425         359.0
# 1  20.0  0.24  0.2273  0.41        83.0   88          91.0
# 2   2.0  0.32  0.3030  0.66         3.0    4           4.0
# 3  19.0  0.78  0.7121  0.52       457.0  526         547.0
# 4   0.0  0.26  0.2273  0.56         8.0   13          10.0

# %%
# !pip install xgboost

# %% [markdown]
# ## Xgboost

# %%
# Xtreme Gradient Boosting (XGBoost)
from xgboost import XGBRegressor
RegModel=XGBRegressor(max_depth=10, learning_rate=0.1, n_estimators=500, objective='reg:linear', booster='gbtree')

# Printing all the parameters of XGBoost
print(RegModel)

# Creating the model on Training Data
XGB=RegModel.fit(X_train,y_train)
prediction=XGB.predict(X_test)

from sklearn import metrics
# Measuring Goodness of fit in Training data
print('R2 Value:',metrics.r2_score(y_train, XGB.predict(X_train)))

# Measuring accuracy on Testing Data
print('Accuracy',100- (np.mean(np.abs((y_test - prediction) / y_test)) * 100))

# Plotting the feature importance for Top 10 most important columns
# %matplotlib inline
feature_importances = pd.Series(XGB.feature_importances_, index=Predictors)
feature_importances.nlargest(10).plot(kind='barh')

# Printing some sample values of prediction
TestingDataResults=pd.DataFrame(data=X_test, columns=Predictors)
TestingDataResults[TargetVariable]=y_test
TestingDataResults[('Predicted'+TargetVariable)]=np.round(prediction)
TestingDataResults.head()
# Out:
# XGBRegressor(base_score=None, booster='gbtree', colsample_bylevel=None,
#              colsample_bynode=None, colsample_bytree=None, gamma=None,
#              gpu_id=None, importance_type='gain', interaction_constraints=None,
#              learning_rate=0.1, max_delta_step=None, max_depth=10,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=500, n_jobs=None, num_parallel_tree=None,
#              objective='reg:linear', random_state=None, reg_alpha=None,
#              reg_lambda=None, scale_pos_weight=None, subsample=None,
#              tree_method=None, validate_parameters=None, verbosity=None)
# [01:37:23] WARNING: /Users/travis/build/dmlc/xgboost/src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# R2 Value: 0.9997531597797757
# Accuracy 89.36679398899538
#      hr  temp   atemp   hum  registered  cnt  Predictedcnt
# 0  19.0  0.80  0.6970  0.27       240.0  425         326.0
# ...

# %% [markdown]
# ## knn

# %%
# K-Nearest Neighbor(KNN)
from sklearn.neighbors import KNeighborsRegressor
RegModel = KNeighborsRegressor(n_neighbors=5)

# Printing all the parameters of KNN
print(RegModel)

# Creating the model on Training Data
KNN=RegModel.fit(X_train,y_train)
prediction=KNN.predict(X_test)

from sklearn import metrics
# Measuring Goodness of fit in Training data
print('R2 Value:',metrics.r2_score(y_train, KNN.predict(X_train)))

# Measuring accuracy on Testing Data
print('Accuracy',100- (np.mean(np.abs((y_test - prediction) / y_test)) * 100))

# Plotting the feature importance for Top 10 most important columns
# There is no built-in method to get feature importance in KNN

# Printing some sample values of prediction
TestingDataResults=pd.DataFrame(data=X_test, columns=Predictors)
TestingDataResults[TargetVariable]=y_test
TestingDataResults[('Predicted'+TargetVariable)]=np.round(prediction)
TestingDataResults.head()
# Out:
# KNeighborsRegressor()
# R2 Value: 0.9794290602899611
# Accuracy 87.758669159563
#      hr  temp   atemp   hum  registered  cnt  Predictedcnt
# 0  19.0  0.80  0.6970  0.27       240.0  425         303.0
# 1  20.0  0.24  0.2273  0.41        83.0   88          90.0
# 2   2.0  0.32  0.3030  0.66         3.0    4           4.0
# 3  19.0  0.78  0.7121  0.52       457.0  526         550.0
# 4   0.0  0.26  0.2273  0.56         8.0   13           9.0

# %% [markdown]
# ## svm

# %%
# Support Vector Machines(SVM)
from sklearn import svm
RegModel = svm.SVR(C=500, kernel='rbf', degree=20, gamma=0.01)

# Printing all the parameters of KNN
print(RegModel)

# Creating the model on Training Data
SVM=RegModel.fit(X_train,y_train)
prediction=SVM.predict(X_test)

from sklearn import metrics
# Measuring Goodness of fit in Training data
print('R2 Value:',metrics.r2_score(y_train, SVM.predict(X_train)))

# Measuring accuracy on Testing Data
print('Accuracy',100- (np.mean(np.abs((y_test - prediction) / y_test)) * 100))

# Plotting the feature importance for Top 10 most important columns
# The built in attribute SVM.coef_ works only for linear kernel
# %matplotlib inline
#feature_importances = pd.Series(SVM.coef_[0], index=Predictors)
#feature_importances.nlargest(10).plot(kind='barh')

# Printing some sample values of prediction
TestingDataResults=pd.DataFrame(data=X_test, columns=Predictors)
TestingDataResults[TargetVariable]=y_test
TestingDataResults[('Predicted'+TargetVariable)]=np.round(prediction)
TestingDataResults.head()
# Out:
# SVR(C=500, degree=20, gamma=0.01)
# R2 Value: 0.9732771067636321
# Accuracy 90.30362504228192
#      hr  temp   atemp   hum  registered  cnt  Predictedcnt
# 0  19.0  0.80  0.6970  0.27       240.0  425         315.0
# 1  20.0  0.24  0.2273  0.41        83.0   88          90.0
# 2   2.0  0.32  0.3030  0.66         3.0    4           3.0
# 3  19.0  0.78  0.7121  0.52       457.0  526         514.0
# 4   0.0  0.26  0.2273  0.56         8.0   13           9.0
