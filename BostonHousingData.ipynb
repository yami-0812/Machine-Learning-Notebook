# %% [markdown]
# <a href="https://colab.research.google.com/github/yami-0812/Machine-Learning-Notebook/blob/main/BostonHousingData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
BostonHousingData=pd.read_csv('C:/Users/HP/Downloads/Python Datasets/Regression Datasets/BostonHousingData.csv')

# %%
BostonHousingData
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
print("The details of the data are as follows")
print(BostonHousingData.info())
print("*"*70)
print(BostonHousingData.describe())
print("*"*70)
print(BostonHousingData.nunique())
# Out:
# The details of the data are as follows
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB
# None
# **********************************************************************
# ...

# %%
fig, subPlot=plt.subplots(nrows=1, ncols=4, figsize=(18,5))
fig.suptitle('Medv vs TAX,PTRATIO,B,LSTAT')
BostonHousingData.plot.scatter(x='TAX',y='MEDV',marker='o',ax=subPlot[0])
BostonHousingData.plot.scatter(x='PTRATIO',y='MEDV',marker='o',ax=subPlot[1])
BostonHousingData.plot.scatter(x='B',y='MEDV',marker='o',ax=subPlot[2])
BostonHousingData.plot.scatter(x='LSTAT',y='MEDV',marker='o',ax=subPlot[3])

# %%
fig, subPlot=plt.subplots(nrows=1, ncols=4, figsize=(18,5))
fig.suptitle('Medv vs RM,AGE,DIS,RAD')
BostonHousingData.plot.scatter(x='RM',y='MEDV',marker='o',ax=subPlot[0])
BostonHousingData.plot.scatter(x='AGE',y='MEDV',marker='o',ax=subPlot[1])
BostonHousingData.plot.scatter(x='DIS',y='MEDV',marker='o',ax=subPlot[2])
BostonHousingData.plot.scatter(x='RAD',y='MEDV',marker='o',ax=subPlot[3])

# %%
import matplotlib.pyplot as plt
fig, subPlot=plt.subplots(nrows=1, ncols=5, figsize=(18,5))
fig.suptitle('Medv vs CRIM,ZN,INDUS,CHAS AND NOX')
BostonHousingData.plot.scatter(x='CRIM',y='MEDV',marker='o',ax=subPlot[0])
BostonHousingData.plot.scatter(x='ZN',y='MEDV',marker='o',ax=subPlot[1])
BostonHousingData.plot.scatter(x='INDUS',y='MEDV',marker='o',ax=subPlot[2])
BostonHousingData.plot.scatter(x='CHAS',y='MEDV',marker='o',ax=subPlot[3])
BostonHousingData.plot.scatter(x='NOX',y='MEDV',marker='o',ax=subPlot[4])
